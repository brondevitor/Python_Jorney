# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Investigation and definition

# %%
nyc_sales = pd.read_csv('nyc-rolling-sales_twentieth.csv')
pd.set_option('display.max_columns', 500)

# %%
nyc_sales.mode()
# Out:
#        Unnamed: 0  BOROUGH             NEIGHBORHOOD  \
# 0               4      1.0  UPPER EAST SIDE (59-79)
# 1               5      NaN                      NaN
# 2               6      NaN                      NaN
# 3               7      NaN                      NaN
# 4               8      NaN                      NaN
# ...           ...      ...                      ...
# 16904       16908      NaN                      NaN
# 16905       16909      NaN                      NaN
# 16906       16910      NaN                      NaN
# 16907       16911      NaN                      NaN
# 16908       16912      NaN                      NaN
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      13 CONDOS - ELEVATOR APARTMENTS                                2
# 1                                              NaN                  NaN
# 2                                              NaN                  NaN
# 3                                              NaN                  NaN
# 4                                              NaN                  NaN
# ...                                            ...                  ...
# 16904                                          NaN                  NaN
# 16905                                          NaN                  NaN
# 16906                                          NaN                  NaN
# 16907                                          NaN                  NaN
# 16908                                          NaN                  NaN
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT         ADDRESS  \
# 0       16.0  1.0                                  R4  50 WEST STREET
# 1        NaN  NaN       NaN                       NaN             NaN
# 2        NaN  NaN       NaN                       NaN             NaN
# 3        NaN  NaN       NaN                       NaN             NaN
# 4        NaN  NaN       NaN                       NaN             NaN
# ...      ...  ...       ...                       ...             ...
# 16904    NaN  NaN       NaN                       NaN             NaN
# 16905    NaN  NaN       NaN                       NaN             NaN
# 16906    NaN  NaN       NaN                       NaN             NaN
# 16907    NaN  NaN       NaN                       NaN             NaN
# 16908    NaN  NaN       NaN                       NaN             NaN
#
#       APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                        10023.0                0.0               0.0
# 1                  NaN       NaN                NaN               NaN
# 2                  NaN       NaN                NaN               NaN
# 3                  NaN       NaN                NaN               NaN
# 4                  NaN       NaN                NaN               NaN
# ...                ...       ...                ...               ...
# 16904              NaN       NaN                NaN               NaN
# 16905              NaN       NaN                NaN               NaN
# 16906              NaN       NaN                NaN               NaN
# 16907              NaN       NaN                NaN               NaN
# 16908              NaN       NaN                NaN               NaN
#
#        TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  YEAR BUILT  \
# 0              1.0              -                 -           0.0
# 1              NaN              NaN               NaN         NaN
# 2              NaN              NaN               NaN         NaN
# 3              NaN              NaN               NaN         NaN
# 4              NaN              NaN               NaN         NaN
# ...            ...              ...               ...         ...
# 16904          NaN              NaN               NaN         NaN
# 16905          NaN              NaN               NaN         NaN
# 16906          NaN              NaN               NaN         NaN
# 16907          NaN              NaN               NaN         NaN
# 16908          NaN              NaN               NaN         NaN
#
#        TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE SALE PRICE  \
# 0                            2.0                             R4        -
# 1                            NaN                            NaN        NaN
# 2                            NaN                            NaN        NaN
# 3                            NaN                            NaN        NaN
# 4                            NaN                            NaN        NaN
# ...                          ...                            ...        ...
# 16904                        NaN                            NaN        NaN
# 16905                        NaN                            NaN        NaN
# 16906                        NaN                            NaN        NaN
# 16907                        NaN                            NaN        NaN
# 16908                        NaN                            NaN        NaN
#
#                  SALE DATE
# 0      2016-09-22 00:00:00
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 16904                  NaN
# 16905                  NaN
# 16906                  NaN
# 16907                  NaN
# 16908                  NaN
#
# [16909 rows x 22 columns]

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      16909 non-null  int64
#  1   BOROUGH                         16909 non-null  int64
#  2   NEIGHBORHOOD                    16909 non-null  object
#  3   BUILDING CLASS CATEGORY         16909 non-null  object
#  4   TAX CLASS AT PRESENT            16909 non-null  object
#  5   BLOCK                           16909 non-null  int64
#  6   LOT                             16909 non-null  int64
#  7   EASE-MENT                       16909 non-null  object
#  8   BUILDING CLASS AT PRESENT       16909 non-null  object
#  9   ADDRESS                         16909 non-null  object
#  10  APARTMENT NUMBER                16909 non-null  object
#  11  ZIP CODE                        16909 non-null  int64
#  12  RESIDENTIAL UNITS               16909 non-null  int64
#  13  COMMERCIAL UNITS                16909 non-null  int64
#  14  TOTAL UNITS                     16909 non-null  int64
#  15  LAND SQUARE FEET                16909 non-null  object
#  16  GROSS SQUARE FEET               16909 non-null  object
#  17  YEAR BUILT                      16909 non-null  int64
#  18  TAX CLASS AT TIME OF SALE       16909 non-null  int64
#  19  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  20  SALE PRICE                      16909 non-null  object
#  21  SALE DATE                       16909 non-null  object
# dtypes: int64(10), object(12)
# memory usage: 2.8+ MB

# %% [markdown]
# First impressions:
# * - We have a column without any value,
# * - Important numeric features in Object mode, lets convert then in a numeric
# * - The feature BOROUGH is in a number type, lets change it to the neighborhood name
# * - Categoric features in INT type, lets convert then in object type

# %%
nyc_sales['SALE PRICE'] = pd.to_numeric(nyc_sales['SALE PRICE'], errors = 'coerce')
nyc_sales['SALE PRICE']
# erros ='coerce' -> when it has an error it will transform into NaN, in this case it does it in the - values
# Out:
# 0        6625000.0
# 1              NaN
# 2              NaN
# 3        3936272.0
# 4        8000000.0
#            ...
# 16904          NaN
# 16905     712500.0
# 16906     740000.0
# 16907    1800000.0
# 16908          NaN
# Name: SALE PRICE, Length: 16909, dtype: float64

# %%
# let's tranform all the others features that must be numeric type
for n in ['GROSS SQUARE FEET', 'LAND SQUARE FEET', 'APARTMENT NUMBER']:
    nyc_sales[n] = pd.to_numeric(nyc_sales[n] , errors = 'coerce')

# %%
# let's transform all the categoric features in object type
for n in ['BLOCK' , 'LOT' , 'TAX CLASS AT TIME OF SALE']:
    nyc_sales[n] = nyc_sales[n].astype('object')

# %%
# For the BOROUGH variables, let's follow the recommendations of the "documentation"
nyc_sales['BOROUGH'] = nyc_sales['BOROUGH'].map({
                                  1: 'Manhatan',
                                  2: 'Bronx' , 
                                  3: 'Brooklyn' , 
                                  4: 'Queens' ,
                                  5: 'State Island'})

# %%
nyc_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16909 entries, 0 to 16908
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      16909 non-null  int64
#  1   BOROUGH                         16909 non-null  object
#  2   NEIGHBORHOOD                    16909 non-null  object
#  3   BUILDING CLASS CATEGORY         16909 non-null  object
#  4   TAX CLASS AT PRESENT            16909 non-null  object
#  5   BLOCK                           16909 non-null  object
#  6   LOT                             16909 non-null  object
#  7   EASE-MENT                       16909 non-null  object
#  8   BUILDING CLASS AT PRESENT       16909 non-null  object
#  9   ADDRESS                         16909 non-null  object
#  10  APARTMENT NUMBER                1156 non-null   float64
#  11  ZIP CODE                        16909 non-null  int64
#  12  RESIDENTIAL UNITS               16909 non-null  int64
#  13  COMMERCIAL UNITS                16909 non-null  int64
#  14  TOTAL UNITS                     16909 non-null  int64
#  15  LAND SQUARE FEET                1731 non-null   float64
#  16  GROSS SQUARE FEET               1621 non-null   float64
#  17  YEAR BUILT                      16909 non-null  int64
#  18  TAX CLASS AT TIME OF SALE       16909 non-null  object
#  19  BUILDING CLASS AT TIME OF SALE  16909 non-null  object
#  20  SALE PRICE                      13395 non-null  float64
#  21  SALE DATE                       16909 non-null  object
# dtypes: float64(4), int64(6), object(12)
# memory usage: 2.8+ MB

# %%
# Finally, we have the SALE DATE column which is a date, but it is a string. Let's convert it to date
nyc_sales['SALE DATE'] = pd.to_datetime(nyc_sales['SALE DATE'], format= '%Y-%m-%d')
# format= '%Y-%m-%d' -> define the date as Year - month - day

# %% [markdown]
# ## Investigation of inconsistencies

# %% [markdown]
# * Dates out of range
# * Feet² or sales price zeroed
# * Negative values of price or feet²

# %%
# checking if we have some date after today
nyc_sales['SALE DATE'].max()
# Out:
# Timestamp('2017-08-31 00:00:00')

# %%
(nyc_sales['SALE DATE']> '2021-06-08').sum()
# Out:
# 0

# %%
# conclusion : we don´t have any date after the current date

# %%
# check if we have area less or igual to 0 
for n in ['SALE PRICE' , 'LAND SQUARE FEET' , 'GROSS SQUARE FEET']:
    if (nyc_sales[n] <= 0 ).sum() > 0:
        print(f'{n} have some inconsistencies')
    else:
        print(f'{n}  OK')
# Out:
# SALE PRICE está OK
# LAND SQUARE FEET está OK
# GROSS SQUARE FEET está OK

# %% [markdown]
# ### Missing values

# %% [markdown]
# Missing data can have several sources:
# * Insertion errors (bank error)
# * human errors
# * Operation errors (sensors)
# * Equipment Faults

# %% [markdown]
# Furthermore, they can be classified as follows
#
# * Missing Completely At Random (MCAR): The data has nothing to do with any data in the dataset. That is, the probability that the missing data exists is not associated with the absence or presence of other information or the column value itself.
# * Missing At Random (MAR): The probability of a missing value occurring is associated with other information in the dataset.
# * Missing Not at Random (MNAR): Missing data has to do with the value itself.

# %% [markdown]
# ### Treatment

# %% [markdown]
# When missing data appears through a join in a table, we are almost always able to fill in the missing data with a value that makes sense. Example: Account withdrawal. Not all customers make withdrawals in a month. This way, we can fill in the missing amount in the cashout column for a customer who didn't cashout as 0.

# %% [markdown]
# Almost never the option to delete everything is the best, as some problems can arise, such as:
#
# Introduction of Bias
# loss of information

# %% [markdown]
# Some methods of handling missing data:
#
# * deletion
# * Filling with statistics (mode for categorical, median or mean for numeric)
# * Population through a template (KNN, Decision Tree)
# * Filling in with business rule
# * Filling with the value above or bellow
# * Filling with the most commun value in the column

# %% [markdown]
# Some good practices:
#
# * Create Categorical Null for column (works for numeric and categorical)
# * Don't drop as first option.

# %%
nyc_sales.shape[0]
# Out:
# 16909

# %%
# find the Nulls
100*(nyc_sales.isnull().sum()/nyc_sales.shape[0])
# Out:
# Unnamed: 0                         0.000000
# BOROUGH                            0.000000
# NEIGHBORHOOD                       0.000000
# BUILDING CLASS CATEGORY            0.000000
# TAX CLASS AT PRESENT               0.000000
# BLOCK                              0.000000
# LOT                                0.000000
# EASE-MENT                          0.000000
# BUILDING CLASS AT PRESENT          0.000000
# ADDRESS                            0.000000
# APARTMENT NUMBER                  93.163404
# ZIP CODE                           0.000000
# RESIDENTIAL UNITS                  0.000000
# COMMERCIAL UNITS                   0.000000
# TOTAL UNITS                        0.000000
# LAND SQUARE FEET                  89.762848
# GROSS SQUARE FEET                 90.413389
# YEAR BUILT                         0.000000
# TAX CLASS AT TIME OF SALE          0.000000
# BUILDING CLASS AT TIME OF SALE     0.000000
# SALE PRICE                        20.781832
# SALE DATE                          0.000000
# dtype: float64

# %% [markdown]
# Treatment Options:
#
# * Delete the Land Square Feet, Gross Square Feet and Apartment Number columns and add a Categorical Null column.
# * Keep the column and categorize (ranges of values) by adding the Categorical Null

# %%
nyc_sales['IS_NULL_APARTMENT_NUMBER'] = False

# %%
nyc_sales.loc[nyc_sales['APARTMENT NUMBER'].isnull(), 'IS_NULL_APARTMENT_NUMBER'] = True

# %%
nyc_sales['IS_NULL_APARTMENT_NUMBER'].sum()/nyc_sales.shape[0]
# Out:
# 0.9316340410432314

# %% [markdown]
# Let's create a column with a range of values and a categorical null, using the ```pd.cut``` function

# %%
nyc_sales['LAND SQUARE FEET RANGE'] = pd.cut(nyc_sales['LAND SQUARE FEET'] , bins = 5)
nyc_sales['LAND SQUARE FEET RANGE'] = nyc_sales['LAND SQUARE FEET RANGE'].astype('object')
nyc_sales['LAND SQUARE FEET RANGE'] = nyc_sales['LAND SQUARE FEET RANGE'].fillna('UNKNOW RANGE')

# %%
nyc_sales['GROSS SQUARE FEET RANGE'] = pd.cut(nyc_sales['GROSS SQUARE FEET'], bins=[0, 100000, 500000, 7500000, np.inf])

# %%
nyc_sales['GROSS SQUARE FEET RANGE'] = nyc_sales['GROSS SQUARE FEET RANGE'].astype('object')
nyc_sales['GROSS SQUARE FEET RANGE'] = nyc_sales['GROSS SQUARE FEET RANGE'].fillna('UNKNOW RANGE')

# %%
nyc_sales['GROSS SQUARE FEET RANGE']
# Out:
# 0        (0.0, 100000.0]
# 1        (0.0, 100000.0]
# 2        (0.0, 100000.0]
# 3        (0.0, 100000.0]
# 4        (0.0, 100000.0]
#               ...
# 16904       UNKNOW RANGE
# 16905       UNKNOW RANGE
# 16906       UNKNOW RANGE
# 16907       UNKNOW RANGE
# 16908       UNKNOW RANGE
# Name: GROSS SQUARE FEET RANGE, Length: 16909, dtype: object

# %%
nyc_sales
# Out:
#        Unnamed: 0   BOROUGH             NEIGHBORHOOD  \
# 0               4  Manhatan            ALPHABET CITY
# 1               5  Manhatan            ALPHABET CITY
# 2               6  Manhatan            ALPHABET CITY
# 3               7  Manhatan            ALPHABET CITY
# 4               8  Manhatan            ALPHABET CITY
# ...           ...       ...                      ...
# 16904       16908  Manhatan  UPPER WEST SIDE (79-96)
# 16905       16909  Manhatan  UPPER WEST SIDE (79-96)
# 16906       16910  Manhatan  UPPER WEST SIDE (79-96)
# 16907       16911  Manhatan  UPPER WEST SIDE (79-96)
# 16908       16912  Manhatan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN     10009                  5                 0
# 1                   NaN     10009                 28                 3
# 2                   NaN     10009                 16                 1
# 3                   NaN     10009                 10                 0
# 4                   NaN     10009                  6                 0
# ...                 ...       ...                ...               ...
# 16904               NaN     10024                  0                 0
# 16905               NaN     10024                  0                 0
# 16906               NaN     10024                  0                 0
# 16907               NaN     10024                  0                 0
# 16908               NaN     10024                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                             C2   6625000.0
# 1                             2                             C7         NaN
# 2                             2                             C7         NaN
# 3                             2                             C4   3936272.0
# 4                             2                             C2   8000000.0
# ...                         ...                            ...         ...
# 16904                         2                             D4         NaN
# 16905                         2                             D4    712500.0
# 16906                         2                             D4    740000.0
# 16907                         2                             D4   1800000.0
# 16908                         2                             D4         NaN
#
#        SALE DATE  IS_NULL_APARTMENT_NUMBER LAND SQUARE FEET RANGE  \
# 0     2017-07-19                      True    (-275.912, 72870.4]
# 1     2016-12-14                      True    (-275.912, 72870.4]
# 2     2016-12-09                      True    (-275.912, 72870.4]
# 3     2016-09-23                      True    (-275.912, 72870.4]
# 4     2016-11-17                      True    (-275.912, 72870.4]
# ...          ...                       ...                    ...
# 16904 2017-02-08                      True           UNKNOW RANGE
# 16905 2017-02-13                      True           UNKNOW RANGE
# 16906 2017-02-13                      True           UNKNOW RANGE
# 16907 2017-04-27                      True           UNKNOW RANGE
# 16908 2017-05-04                      True           UNKNOW RANGE
#
#       GROSS SQUARE FEET RANGE
# 0             (0.0, 100000.0]
# 1             (0.0, 100000.0]
# 2             (0.0, 100000.0]
# 3             (0.0, 100000.0]
# 4             (0.0, 100000.0]
# ...                       ...
# 16904            UNKNOW RANGE
# 16905            UNKNOW RANGE
# 16906            UNKNOW RANGE
# 16907            UNKNOW RANGE
# 16908            UNKNOW RANGE
#
# [16909 rows x 25 columns]

# %%
# Another exemples

# %%
# creating a random dataframe
df_random = pd.DataFrame(np.random.randint(0,100 , size = (5,4)), columns = ['A' , 'B' , 'C' , 'D'])
df_random
# Out:
#     A   B   C   D
# 0  37  29   8  18
# 1  46  59  59  87
# 2  25  28  32  15
# 3  71  71  57  30
# 4  48   4  66  92

# %%
df_random.iloc[0:2, 2] = np.nan
df_random.iloc[[1,2], 0] = np.nan
df_random.iloc[[2, 3], 3] = np.nan

# %%
df_random
# Out:
#       A   B     C     D
# 0  37.0  29   NaN  18.0
# 1   NaN  59   NaN  87.0
# 2   NaN  28  32.0   NaN
# 3  71.0  71  57.0   NaN
# 4  48.0   4  66.0  92.0

# %%
df_random['A'].mean()
# Out:
# 52.0

# %%
# using the mean to fill the NaN
df_random['A'] = df_random['A'].fillna(df_random['A'].mean())

# %%
df_random
# Out:
#       A   B     C     D
# 0  37.0  29   NaN  18.0
# 1  52.0  59   NaN  87.0
# 2  52.0  28  32.0   NaN
# 3  71.0  71  57.0   NaN
# 4  48.0   4  66.0  92.0

# %%
# Backward Fill
df_random['C'] = df_random['C'].fillna(method='bfill')

# %%
df_random
# Out:
#       A   B     C     D
# 0  37.0  29  32.0  18.0
# 1  52.0  59  32.0  87.0
# 2  52.0  28  32.0   NaN
# 3  71.0  71  57.0   NaN
# 4  48.0   4  66.0  92.0

# %%
# Forward fill
df_random['D'] = df_random['D'].fillna(method='ffill')

# %%
df_random
# Out:
#       A   B     C     D
# 0  37.0  29  32.0  18.0
# 1  52.0  59  32.0  87.0
# 2  52.0  28  32.0  87.0
# 3  71.0  71  57.0  87.0
# 4  48.0   4  66.0  92.0

# %% [markdown]
# # Analysis of Duplicates

# %% [markdown]
# Duplicates are records that are the same in their entirety or in a specific set of columns. In addition, we may also have equivalent and duplicate columns in our dataset that we don't want to keep as it creates redundancy. And in an eventual machine learning model training process this can lead to overfitting or overestimation of performance (in the case of duplicate rows)

# %% [markdown]
# To remove duplicates we use the ```drop_duplicates()``` function

# %%
# Without passing anything it observes if there is an exact match between any line and keeps only the first line it found
nyc_sales.drop_duplicates(keep='first')
# we can have keep=last (keep the last line) or keep = False (keep none)
# Out:
#        Unnamed: 0   BOROUGH             NEIGHBORHOOD  \
# 0               4  Manhatan            ALPHABET CITY
# 1               5  Manhatan            ALPHABET CITY
# 2               6  Manhatan            ALPHABET CITY
# 3               7  Manhatan            ALPHABET CITY
# 4               8  Manhatan            ALPHABET CITY
# ...           ...       ...                      ...
# 16904       16908  Manhatan  UPPER WEST SIDE (79-96)
# 16905       16909  Manhatan  UPPER WEST SIDE (79-96)
# 16906       16910  Manhatan  UPPER WEST SIDE (79-96)
# 16907       16911  Manhatan  UPPER WEST SIDE (79-96)
# 16908       16912  Manhatan  UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 1      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 2      07 RENTALS - WALKUP APARTMENTS                                 2   399
# 3      07 RENTALS - WALKUP APARTMENTS                                2B   402
# 4      07 RENTALS - WALKUP APARTMENTS                                2A   404
# ...                                            ...                  ...   ...
# 16904  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16905  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16906  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16907  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
# 16908  10 COOPS - ELEVATOR APARTMENTS                                 2  1237
#
#       LOT EASE-MENT BUILDING CLASS AT PRESENT                    ADDRESS  \
# 0       6                                  C2               153 AVENUE B
# 1      26                                  C7      234 EAST 4TH   STREET
# 2      39                                  C7      197 EAST 3RD   STREET
# 3      21                                  C4        154 EAST 7TH STREET
# 4      55                                  C2     301 EAST 10TH   STREET
# ...    ..       ...                       ...                        ...
# 16904  29                                  D4   201 WEST 89TH STREET, 9A
# 16905  29                                  D4  201 WEST 89TH STREET, 10C
# 16906  29                                  D4        201 WEST 89 ST, 10D
# 16907  29                                  D4   201 WEST 89TH STREET, 7G
# 16908  29                                  D4      201 W 89TH STREET, 8E
#
#        APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN     10009                  5                 0
# 1                   NaN     10009                 28                 3
# 2                   NaN     10009                 16                 1
# 3                   NaN     10009                 10                 0
# 4                   NaN     10009                  6                 0
# ...                 ...       ...                ...               ...
# 16904               NaN     10024                  0                 0
# 16905               NaN     10024                  0                 0
# 16906               NaN     10024                  0                 0
# 16907               NaN     10024                  0                 0
# 16908               NaN     10024                  0                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 1               31            4616.0            18690.0        1900
# 2               17            2212.0             7803.0        1900
# 3               10            2272.0             6794.0        1913
# 4                6            2369.0             4615.0        1900
# ...            ...               ...                ...         ...
# 16904            0               NaN                NaN        1925
# 16905            0               NaN                NaN        1925
# 16906            0               NaN                NaN        1925
# 16907            0               NaN                NaN        1925
# 16908            0               NaN                NaN        1925
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 0                             2                             C2   6625000.0
# 1                             2                             C7         NaN
# 2                             2                             C7         NaN
# 3                             2                             C4   3936272.0
# 4                             2                             C2   8000000.0
# ...                         ...                            ...         ...
# 16904                         2                             D4         NaN
# 16905                         2                             D4    712500.0
# 16906                         2                             D4    740000.0
# 16907                         2                             D4   1800000.0
# 16908                         2                             D4         NaN
#
#        SALE DATE  IS_NULL_APARTMENT_NUMBER LAND SQUARE FEET RANGE  \
# 0     2017-07-19                      True    (-275.912, 72870.4]
# 1     2016-12-14                      True    (-275.912, 72870.4]
# 2     2016-12-09                      True    (-275.912, 72870.4]
# 3     2016-09-23                      True    (-275.912, 72870.4]
# 4     2016-11-17                      True    (-275.912, 72870.4]
# ...          ...                       ...                    ...
# 16904 2017-02-08                      True           UNKNOW RANGE
# 16905 2017-02-13                      True           UNKNOW RANGE
# 16906 2017-02-13                      True           UNKNOW RANGE
# 16907 2017-04-27                      True           UNKNOW RANGE
# 16908 2017-05-04                      True           UNKNOW RANGE
#
#       GROSS SQUARE FEET RANGE
# 0             (0.0, 100000.0]
# 1             (0.0, 100000.0]
# 2             (0.0, 100000.0]
# 3             (0.0, 100000.0]
# 4             (0.0, 100000.0]
# ...                       ...
# 16904            UNKNOW RANGE
# 16905            UNKNOW RANGE
# 16906            UNKNOW RANGE
# 16907            UNKNOW RANGE
# 16908            UNKNOW RANGE
#
# [16909 rows x 25 columns]

# %%
# The subset parameter gives us the freedom to look for duplicates only in a set of columns
nyc_sales.drop_duplicates(subset= ['BOROUGH','NEIGHBORHOOD'])
# we can have keep=last (keep the last line) or keep = False (keep none)
# Out:
#        Unnamed: 0   BOROUGH               NEIGHBORHOOD  \
# 0               4  Manhatan              ALPHABET CITY
# 204           208  Manhatan                    CHELSEA
# 1007         1011  Manhatan                  CHINATOWN
# 1122         1126  Manhatan               CIVIC CENTER
# 1445         1449  Manhatan                    CLINTON
# 1791         1795  Manhatan               EAST VILLAGE
# 1969         1973  Manhatan                    FASHION
# 2090         2094  Manhatan                  FINANCIAL
# 2586         2590  Manhatan                   FLATIRON
# 3059         3063  Manhatan                   GRAMERCY
# 3533         3537  Manhatan  GREENWICH VILLAGE-CENTRAL
# 4171         4175  Manhatan     GREENWICH VILLAGE-WEST
# 4797         4801  Manhatan             HARLEM-CENTRAL
# 5644         5648  Manhatan                HARLEM-EAST
# 5988         5992  Manhatan               HARLEM-UPPER
# 6129         6133  Manhatan                HARLEM-WEST
# 6167         6171  Manhatan                     INWOOD
# 6286         6290  Manhatan              JAVITS CENTER
# 6327         6331  Manhatan                   KIPS BAY
# 6697         6701  Manhatan               LITTLE ITALY
# 6738         6742  Manhatan            LOWER EAST SIDE
# 7040         7044  Manhatan           MANHATTAN VALLEY
# 7274         7278  Manhatan                MIDTOWN CBD
# 7474         7478  Manhatan               MIDTOWN EAST
# 8892         8896  Manhatan               MIDTOWN WEST
# 9810         9814  Manhatan        MORNINGSIDE HEIGHTS
# 9882         9886  Manhatan                MURRAY HILL
# 10503       10507  Manhatan           ROOSEVELT ISLAND
# 10571       10575  Manhatan                       SOHO
# 10887       10891  Manhatan                SOUTHBRIDGE
# 11029       11033  Manhatan                    TRIBECA
# 11684       11688  Manhatan    UPPER EAST SIDE (59-79)
# 13420       13424  Manhatan    UPPER EAST SIDE (79-96)
# 15010       15014  Manhatan   UPPER EAST SIDE (96-110)
# 15065       15069  Manhatan    UPPER WEST SIDE (59-79)
# 16504       16508  Manhatan    UPPER WEST SIDE (79-96)
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A   392
# 204    01 ONE FAMILY DWELLINGS                                        1   766
# 1007   07 RENTALS - WALKUP APARTMENTS                                 2   162
# 1122   07 RENTALS - WALKUP APARTMENTS                                2B   175
# 1445   07 RENTALS - WALKUP APARTMENTS                                 2  1053
# 1791   02 TWO FAMILY DWELLINGS                                        1   436
# 1969   07 RENTALS - WALKUP APARTMENTS                                 2   762
# 2090   08 RENTALS - ELEVATOR APARTMENTS                               2    27
# 2586   08 RENTALS - ELEVATOR APARTMENTS                               2   844
# 3059   02 TWO FAMILY DWELLINGS                                        1   873
# 3533   01 ONE FAMILY DWELLINGS                                        1   525
# 4171   01 ONE FAMILY DWELLINGS                                        1   584
# 4797   01 ONE FAMILY DWELLINGS                                        1  1829
# 5644   01 ONE FAMILY DWELLINGS                                        1  1625
# 5988   01 ONE FAMILY DWELLINGS                                        1  2058
# 6129   01 ONE FAMILY DWELLINGS                                        1  2071
# 6167   01 ONE FAMILY DWELLINGS                                        1  2215
# 6286   02 TWO FAMILY DWELLINGS                                        1   733
# 6327   02 TWO FAMILY DWELLINGS                                        1   924
# 6697   01 ONE FAMILY DWELLINGS                                        1   471
# 6738   02 TWO FAMILY DWELLINGS                                        1   288
# 7040   03 THREE FAMILY DWELLINGS                                      1  1847
# 7274   10 COOPS - ELEVATOR APARTMENTS                                 2  1293
# 7474   01 ONE FAMILY DWELLINGS                                        1  1322
# 8892   07 RENTALS - WALKUP APARTMENTS                                2B  1009
# 9810   07 RENTALS - WALKUP APARTMENTS                                 2  1993
# 9882   01 ONE FAMILY DWELLINGS                                        1   893
# 10503  10 COOPS - ELEVATOR APARTMENTS                                 2  1373
# 10571  01 ONE FAMILY DWELLINGS                                        1   490
# 10887  08 RENTALS - ELEVATOR APARTMENTS                               2    92
# 11029  09 COOPS - WALKUP APARTMENTS                                  2C   193
# 11684  01 ONE FAMILY DWELLINGS                                        1  1380
# 13420  01 ONE FAMILY DWELLINGS                                        1  1491
# 15010  07 RENTALS - WALKUP APARTMENTS                                 2  1610
# 15065  01 ONE FAMILY DWELLINGS                                        1  1126
# 16504  01 ONE FAMILY DWELLINGS                                        1  1197
#
#        LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0        6                                  C2            153 AVENUE B
# 204     13                                  A9  251 WEST 16TH   STREET
# 1007    15                                  C7          28 MOTT STREET
# 1122    19                                  C7         41 WHITE STREET
# 1445     4                                  C7       602 10TH   AVENUE
# 1791     1                                  S2            138 1 AVENUE
# 1969    17                                  C4    331 WEST 38TH STREET
# 2090     9                                  D5          63 WALL STREET
# 2586     8                                  D6    9 EAST 16TH   STREET
# 3059    31                                  S2  141 EAST 17TH   STREET
# 3533    34                                  S1     168 THOMPSON STREET
# 4171    31                                  A4       75 BEDFORD STREET
# 4797   125                                  A4     221 WEST 113 STREET
# 5644   101                                  A9   101B EAST 97TH STREET
# 5988     6                                  A9     465 WEST 141 STREET
# 6129   141                                  A9   516 WEST 140TH STREET
# 6167   510                                  A5   49 MARBLE HILL AVENUE
# 6286    63                                  S2    448 WEST 36TH STREET
# 6327    11                                  B9  313 EAST 18TH   STREET
# 6697     2                                  A4   2 CENTRE MARKET PLACE
# 6738    36                                  S2        527 GRAND STREET
# 7040    11                                  C0     317 WEST 112 STREET
# 7274    37                                  D4    470 PARK AVENUE, 11B
# 7474     8                                  A4  213 EAST 48TH   STREET
# 8892    16                                  C7    129 WEST 56TH STREET
# 9810    82                                  C7           3151 BROADWAY
# 9882    71                                  A4  132 EAST 38TH   STREET
# 10503    1                                  D4           40 RIVER ROAD
# 10571   28                                  A7      40 SULLIVAN STREET
# 10887    3                                  D5  165-167 WILLIAM STREET
# 11029   15                                  C8      38 WHITE STREET, 2
# 11684  143                                  A7     58 EAST 66TH STREET
# 13420   43                                  A4   62 EAST 80TH   STREET
# 15010    9                                  C1   21-23 EAST 104 STREET
# 15065   11                                  A4     43 WEST 73RD STREET
# 16504   18                                  A9   35 WEST 83RD   STREET
#
#        APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0                   NaN     10009                  5                 0
# 204                 NaN     10011                  1                 0
# 1007                NaN     10013                 17                 1
# 1122                NaN     10013                  7                 1
# 1445                NaN     10036                 14                 1
# 1791                NaN     10009                  2                 1
# 1969                NaN     10018                 16                 2
# 2090                NaN     10005                476                 6
# 2586                NaN     10003                 15                 1
# 3059                NaN     10003                  2                 1
# 3533                NaN     10012                  1                 1
# 4171                NaN     10014                  1                 0
# 4797                NaN     10026                  1                 0
# 5644                NaN     10029                  1                 0
# 5988                NaN     10031                  1                 0
# 6129                NaN     10031                  1                 0
# 6167                NaN     10463                  1                 0
# 6286                NaN     10018                  2                 1
# 6327                NaN     10003                  2                 0
# 6697                NaN     10013                  1                 0
# 6738                NaN     10002                  2                 1
# 7040                NaN     10026                  3                 0
# 7274                NaN     10022                  0                 0
# 7474                NaN     10017                  1                 0
# 8892                NaN     10019                  8                 1
# 9810                NaN     10027                 21                 2
# 9882                NaN     10016                  1                 0
# 10503               NaN     10044                  0                 0
# 10571               NaN     10013                  1                 0
# 10887               NaN     10038                 12                 1
# 11029               NaN     10013                  0                 0
# 11684               NaN     10065                  1                 0
# 13420               NaN     10075                  1                 0
# 15010               NaN     10029                 32                 0
# 15065               NaN     10023                  1                 0
# 16504               NaN     10024                  1                 0
#
#        TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 0                5            1633.0             6440.0        1900
# 204              1            1360.0             2736.0        1910
# 1007            18            2307.0             8577.0        1920
# 1122             8            2633.0            12000.0        1915
# 1445            15            2217.0             9475.0        1910
# 1791             3            1200.0             3360.0        1900
# 1969            18            2475.0             9690.0        1920
# 2090           482           17623.0           400531.0        1929
# 2586            16            4600.0            30680.0        1900
# 3059             3            2300.0             6720.0        1920
# 3533             2            1350.0             5807.0        1900
# 4171             1            1640.0             2400.0        1901
# 4797             1            1682.0             2727.0        1910
# 5644             1             847.0             1472.0        1925
# 5988             1            1799.0             6264.0        1920
# 6129             1            1499.0             2845.0        1899
# 6167             1            1219.0             1224.0        1920
# 6286             3            2469.0             4747.0        1910
# 6327             2            1840.0             2880.0        1910
# 6697             1            1016.0             3700.0        1800
# 6738             3            1238.0             3714.0        1910
# 7040             3            1682.0             3333.0        1900
# 7274             0               NaN                NaN        1916
# 7474             1            1665.0             3060.0        1899
# 8892             9            2092.0             8180.0        1920
# 9810            23            4158.0            16377.0        1905
# 9882             1             495.0             1920.0        1910
# 10503            0               NaN                NaN        1975
# 10571            1            2100.0             4607.0        2015
# 10887           13            3480.0            31073.0        1908
# 11029            0               NaN                NaN        1915
# 11684            1            2008.0             9600.0        1922
# 13420            1            1839.0             5280.0        1899
# 15010           32            5046.0            26100.0        1930
# 15065            1            2146.0             6485.0        1910
# 16504            1            1600.0             3750.0        1901
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE   SALE PRICE  \
# 0                             2                             C2    6625000.0
# 204                           1                             A9          NaN
# 1007                          2                             C7          NaN
# 1122                          2                             C7  141500000.0
# 1445                          2                             C7          NaN
# 1791                          1                             S2    3000000.0
# 1969                          2                             C4          NaN
# 2090                          2                             D5  239114603.0
# 2586                          2                             D6          NaN
# 3059                          1                             S2    5300000.0
# 3533                          1                             S1    9999999.0
# 4171                          1                             A4    7800000.0
# 4797                          1                             A4          NaN
# 5644                          1                             A9          NaN
# 5988                          1                             A9          NaN
# 6129                          1                             A9    2260000.0
# 6167                          1                             A5     635000.0
# 6286                          1                             S2    6100000.0
# 6327                          1                             B9    4600000.0
# 6697                          1                             A4    7090000.0
# 6738                          1                             S2          NaN
# 7040                          1                             C0    3075000.0
# 7274                          2                             D4    2000000.0
# 7474                          1                             A4    5000000.0
# 8892                          2                             C7          NaN
# 9810                          2                             C7          NaN
# 9882                          1                             A4    3850000.0
# 10503                         2                             D4    4127983.0
# 10571                         1                             A7          NaN
# 10887                         2                             D5   19000000.0
# 11029                         2                             C8    3700000.0
# 11684                         1                             A7   24175000.0
# 13420                         1                             A4          NaN
# 15010                         2                             C1    1741816.0
# 15065                         1                             A4   15500000.0
# 16504                         1                             A9          NaN
#
#        SALE DATE  IS_NULL_APARTMENT_NUMBER LAND SQUARE FEET RANGE  \
# 0     2017-07-19                      True    (-275.912, 72870.4]
# 204   2017-01-06                      True    (-275.912, 72870.4]
# 1007  2017-06-16                      True    (-275.912, 72870.4]
# 1122  2017-07-13                      True    (-275.912, 72870.4]
# 1445  2016-11-04                      True    (-275.912, 72870.4]
# 1791  2017-08-31                      True    (-275.912, 72870.4]
# 1969  2016-12-23                      True    (-275.912, 72870.4]
# 2090  2016-09-30                      True    (-275.912, 72870.4]
# 2586  2017-01-30                      True    (-275.912, 72870.4]
# 3059  2017-08-03                      True    (-275.912, 72870.4]
# 3533  2016-11-22                      True    (-275.912, 72870.4]
# 4171  2017-08-15                      True    (-275.912, 72870.4]
# 4797  2016-12-15                      True    (-275.912, 72870.4]
# 5644  2017-03-07                      True    (-275.912, 72870.4]
# 5988  2016-12-15                      True    (-275.912, 72870.4]
# 6129  2016-10-19                      True    (-275.912, 72870.4]
# 6167  2017-08-18                      True    (-275.912, 72870.4]
# 6286  2017-01-13                      True    (-275.912, 72870.4]
# 6327  2016-09-02                      True    (-275.912, 72870.4]
# 6697  2017-03-09                      True    (-275.912, 72870.4]
# 6738  2017-02-14                      True    (-275.912, 72870.4]
# 7040  2017-03-20                      True    (-275.912, 72870.4]
# 7274  2016-11-28                      True           UNKNOW RANGE
# 7474  2017-02-15                      True    (-275.912, 72870.4]
# 8892  2016-12-13                      True    (-275.912, 72870.4]
# 9810  2016-09-21                      True    (-275.912, 72870.4]
# 9882  2017-07-10                      True    (-275.912, 72870.4]
# 10503 2016-11-01                      True           UNKNOW RANGE
# 10571 2017-07-14                      True    (-275.912, 72870.4]
# 10887 2017-02-10                      True    (-275.912, 72870.4]
# 11029 2017-04-06                      True           UNKNOW RANGE
# 11684 2017-02-10                      True    (-275.912, 72870.4]
# 13420 2017-04-01                      True    (-275.912, 72870.4]
# 15010 2017-06-29                      True    (-275.912, 72870.4]
# 15065 2017-01-12                      True    (-275.912, 72870.4]
# 16504 2017-01-31                      True    (-275.912, 72870.4]
#
#       GROSS SQUARE FEET RANGE
# 0             (0.0, 100000.0]
# 204           (0.0, 100000.0]
# 1007          (0.0, 100000.0]
# 1122          (0.0, 100000.0]
# 1445          (0.0, 100000.0]
# 1791          (0.0, 100000.0]
# 1969          (0.0, 100000.0]
# 2090     (100000.0, 500000.0]
# 2586          (0.0, 100000.0]
# 3059          (0.0, 100000.0]
# 3533          (0.0, 100000.0]
# 4171          (0.0, 100000.0]
# 4797          (0.0, 100000.0]
# 5644          (0.0, 100000.0]
# 5988          (0.0, 100000.0]
# 6129          (0.0, 100000.0]
# 6167          (0.0, 100000.0]
# 6286          (0.0, 100000.0]
# 6327          (0.0, 100000.0]
# 6697          (0.0, 100000.0]
# 6738          (0.0, 100000.0]
# 7040          (0.0, 100000.0]
# 7274             UNKNOW RANGE
# 7474          (0.0, 100000.0]
# 8892          (0.0, 100000.0]
# 9810          (0.0, 100000.0]
# 9882          (0.0, 100000.0]
# 10503            UNKNOW RANGE
# 10571         (0.0, 100000.0]
# 10887         (0.0, 100000.0]
# 11029            UNKNOW RANGE
# 11684         (0.0, 100000.0]
# 13420         (0.0, 100000.0]
# 15010         (0.0, 100000.0]
# 15065         (0.0, 100000.0]
# 16504         (0.0, 100000.0]

# %%
nyc_sales['DUPLICATED_BLOCK'] =  nyc_sales['BLOCK']

# %% [markdown]
# ## Removing Constant Columns

# %% [markdown]
# A constant column does not aggregate information for any analysis. We usually exclude.

# %%
# we can scan the columns with a foor lop and identify which columns have only one possible padding value
colunas_constantes = []
for col in nyc_sales.columns:
    if len(nyc_sales[col].unique()) == 1:
        colunas_constantes.append(col)
    else:
        print(f'{col} OK')
# Out:
# Unnamed: 0 OK
# NEIGHBORHOOD OK
# BUILDING CLASS CATEGORY OK
# TAX CLASS AT PRESENT OK
# BLOCK OK
# LOT OK
# BUILDING CLASS AT PRESENT OK
# ADDRESS OK
# APARTMENT NUMBER OK
# ZIP CODE OK
# RESIDENTIAL UNITS OK
# COMMERCIAL UNITS OK
# TOTAL UNITS OK
# LAND SQUARE FEET OK
# GROSS SQUARE FEET OK
# YEAR BUILT OK
# TAX CLASS AT TIME OF SALE OK
# BUILDING CLASS AT TIME OF SALE OK
# SALE PRICE OK
# SALE DATE OK
# IS_NULL_APARTMENT_NUMBER OK
# LAND SQUARE FEET RANGE OK
# GROSS SQUARE FEET RANGE OK
# DUPLICATED_BLOCK OK

# %% [markdown]
# constant_columns

# %% [markdown]
# ## Removal By Low Variance

# %% [markdown]
# Variance is a measure of how spread out your data is around the mean.

# %% [markdown]
# The data from set 2 are more dispersed and, therefore, we say that it has greater variance in relation to the first set.

# %% [markdown]
# When we collect data to use in a machine learning model, it is interesting that they have a minimum level of variance. In this way, we will filter columns whose variance is very close to zero (remember that we have already eliminated those that had all the elements the same).

# %% [markdown]
# Set 1 below has a single different value (6) that varies by 1 unit in relation to the others. Set 2, in turn, also has only one value different from the others (600) and 100 units more than the others. Proportionally, the two sets vary on the same scale. But by calculating the variance, they are different.

# %% [markdown]
# Let's demonstrate how to remove columns (variables with low variance) from the dataset.

# %% [markdown]
# First of all we need to scale our data before calculating the variance. Let's do this using Scikit-Learn's MinMaxScaler.

# %% [markdown]
# # <img src="https://media.geeksforgeeks.org/wp-content/uploads/min-max-normalisation.jpg" heigh=350 width=350>

# %%
data_1 = np.array([5,5,6,5,5])
data_1.mean()
# Out:
# 5.2

# %%
data_2 = np.array([500, 500, 600, 500, 500])
data_2.mean()
# Out:
# 520.0

# %%
np.std(data_1)
# Out:
# 0.39999999999999997

# %%
np.std(data_2)
# Out:
# 40.0

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
data_1_escalado = minmax.fit_transform(data_1.reshape(-1,1))
data_2_escalado = minmax.fit_transform(data_2.reshape(-1,1))

# the reshape is because the function needs the array to be 2 dimensional -> it needs columns

# %%
np.var(data_1_escalado)
# Out:
# 0.16000000000000006

# %%
data_1_escalado
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.]])

# %%
np.var(data_2_escalado)
# Out:
# 0.16000000000000006

# %%
variaveis_numericas_nyc = nyc_sales.select_dtypes(include=['int', 'float'])
variaveis_numericas_escaladas_nyc = minmax.fit_transform(variaveis_numericas_nyc)

# %%
variaveis_numericas_escaladas_nyc = pd.DataFrame(variaveis_numericas_escaladas_nyc, columns=variaveis_numericas_nyc.columns)

# %%
listLowVariance = []
for col in variaveis_numericas_escaladas_nyc.columns:
    if np.var(variaveis_numericas_escaladas_nyc[col]) > 0.001:
        print(f'{col} has considerable variance')
    else:
        print(f'{col} has low variance')
        listLowVariance.append(col)
# Out:
# Unnamed: 0 has considerable variance
# APARTMENT NUMBER has considerable variance
# ZIP CODE has considerable variance
# RESIDENTIAL UNITS has low variance
# COMMERCIAL UNITS has low variance
# TOTAL UNITS has low variance
# LAND SQUARE FEET has considerable variance
# GROSS SQUARE FEET has considerable variance
# YEAR BUILT has considerable variance
# SALE PRICE has low variance

# %%
listLowVariance
# Out:
# ['RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'SALE PRICE']
